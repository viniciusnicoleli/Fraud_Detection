# %% [markdown]
# # Credit Card Fraud Detection

# %% [markdown]
#  The dataset has been collected and analysed during a research collaboration of Worldline and the Machine Learning Group (http://mlg.ulb.ac.be) of ULB (Université Libre de Bruxelles) on big data mining and fraud detection.

# %% [markdown]
# ### Objetivo do Case
#
# Intenção do presente Case, é apresentar 2 modelos que sejam capazes de prever um novo caso de fraude.
#
# Os modelos escolhidos consistem:
#
#     Modelo de Árvore de Decisões (Classificação)
#
#     Modelo: Regressão Logística
#
# Devido a natureza da variável de interesse 'Class' que classifica se a operação é uma fraude ou não (0 e 1), utilizamos tal modelo para a construção do case.

# %% [markdown]
# ## Rodando os pacotes Necessários

# %%
import sklearn as sk
import numpy as np
import pandas as pd
import os as os
import random
from random import sample
from matplotlib import pyplot as plt
from statsmodels.stats.outliers_influence import variance_inflation_factor
import seaborn as sns
from boruta import BorutaPy
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn.model_selection import cross_validate
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# %%
# !pip install boruta
# Out:
# Requirement already satisfied: boruta in c:\users\vinic\anaconda3\lib\site-packages (0.3)
# Requirement already satisfied: scikit-learn>=0.17.1 in c:\users\vinic\anaconda3\lib\site-packages (from boruta) (0.24.2)
# Requirement already satisfied: numpy>=1.10.4 in c:\users\vinic\anaconda3\lib\site-packages (from boruta) (1.20.3)
# Requirement already satisfied: scipy>=0.17.0 in c:\users\vinic\anaconda3\lib\site-packages (from boruta) (1.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\vinic\anaconda3\lib\site-packages (from scikit-learn>=0.17.1->boruta) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\vinic\anaconda3\lib\site-packages (from scikit-learn>=0.17.1->boruta) (1.1.0)

# %% [markdown]
# Descobrindo o caminho do arquivo

# %%
caminho = os.getcwd()
print(caminho)
# Out:
# C:\Users\u122097\Documents

# %% [markdown]
# Interpretando a base de dados

# %%
base = pd.read_csv('creditcard.csv', sep = ',')
base.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
#rodando informações do summary
base.describe()
print(base.columns)
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %% [markdown]
# # Plotando as distribuições das Features

# %%
plt.figure(figsize=(16,24))
numRange= [i for i in range(1,29)]
for i in numRange:
    plt.subplot(6,5,i,aspect='auto')
    indice = 'V'+str(i)
    sns.histplot(base,x=indice)

# %% [markdown]
# # Rodando um VIF para compreender a Multicolinearidade dos dados em relação com a resposta

# %% [markdown]
# A ideia é conseguir distinguir quais features vamos utilizar para o modelo de árvore de decisão

# %%
def calculate_vif(dataset):
    vif = pd.DataFrame()
    vif['features'] = dataset.columns
    vif['VIF_Value'] = [variance_inflation_factor(dataset.values, i) for i in range(dataset.shape[1])]
    
    return(vif)

# %%
features = base.iloc[:,:-1]
print(calculate_vif(features))
# Out:
#    features  VIF_Value
# 0      Time   2.339084
# 1        V1   1.621694
# 2        V2   3.869377
# 3        V3   1.255585
# 4        V4   1.137944
# 5        V5   2.753075
# 6        V6   1.522122
# 7        V7   2.510165
# 8        V8   1.097151
# 9        V9   1.018831
# 10      V10   1.115668
# 11      V11   1.028861
# 12      V12   1.011961
# 13      V13   1.003434
# 14      V14   1.026832
# 15      V15   1.014135
# 16      V16   1.000371
# 17      V17   1.004772
# 18      V18   1.006568
# 19      V19   1.037809
# 20      V20   2.233934
# 21      V21   1.100720
# 22      V22   1.082384
# 23      V23   1.149268
# 24      V24   1.000659
# 25      V25   1.013388
# 26      V26   1.000487
# 27      V27   1.008979
# 28      V28   1.001425
# 29   Amount  11.499791

# %% [markdown]
# # Utilizando a correlação de Pearson devido a escala intervalar dos dados afim de excluir variáveis com as mesmas informações

# %%
# Utilizando Spearman devido a não Normalidade da resposta.
corr = base.corr(method = 'spearman')
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_812c0_row0_col0, #T_812c0_row1_col1, #T_812c0_row2_col2, #T_812c0_row3_col3, #T_812c0_row4_col4, #T_812c0_row5_col5, #T_812c0_row6_col6, #T_812c0_row7_col7, #T_812c0_row8_col8, #T_812c0_row9_col9, #T_812c0_row10_col10, #T_812c0_row11_col11, #T_812c0_row12_col12, #T_812c0_row13_col13, #T_812c0_row14_col14, #T_812c0_row15_col15, #T_812c0_row16_col16, #T_812c0_row17_col17, #T_812c0_row18_col18, #T_812c0_row19_col19, #T_812c0_row20_col20, #T_812c0_row21_col21, #T_812c0_row22_col22, #T_812c0_row23_col23, #T_812c0_row24_col24, #T_812c0_row25_col25, #T_812c0_row26_col26, #T_812c0_row27_col27, #T_812c0_row28_col28, #T_812c0_row29_col29, #T_812c0_row30_col30 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_812c0_row0_col1, #T_812c0_row28_col2 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_812c0_row0_col2, #T_812c0_row10_col0, #T_812c0_row13_col29, #T_812c0_row14_col29, #T_812c0_row16_col23, #T_812c0_row20_col25, #T_812c0_row30_col29 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_812c0_row0_col3, #T_812c0_row0_col4, #T_812c0_row0_col11, #T_812c0_row0_col15, #T_812c0_row1_col20, #T_812c0_row1_col28, #T_812c0_row2_col29, #T_812c0_row3_col0, #T_812c0_row3_col1, #T_812c0_row6_col24, #T_812c0_row7_col6, #T_812c0_row7_col8, #T_812c0_row8_col7, #T_812c0_row8_col13, #T_812c0_row9_col10, #T_812c0_row10_col9, #T_812c0_row12_col30, #T_812c0_row14_col30, #T_812c0_row16_col17, #T_812c0_row17_col12, #T_812c0_row17_col14, #T_812c0_row17_col16, #T_812c0_row17_col18, #T_812c0_row23_col19, #T_812c0_row23_col21, #T_812c0_row23_col22, #T_812c0_row23_col25, #T_812c0_row25_col23, #T_812c0_row26_col27, #T_812c0_row27_col26, #T_812c0_row29_col2, #T_812c0_row29_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_812c0_row0_col5, #T_812c0_row22_col0 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_812c0_row0_col6, #T_812c0_row0_col26, #T_812c0_row9_col27, #T_812c0_row11_col15, #T_812c0_row13_col26, #T_812c0_row15_col13, #T_812c0_row15_col24, #T_812c0_row19_col28, #T_812c0_row23_col26, #T_812c0_row26_col14, #T_812c0_row29_col12, #T_812c0_row29_col14 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_812c0_row0_col7, #T_812c0_row4_col1, #T_812c0_row18_col29, #T_812c0_row19_col20, #T_812c0_row24_col23 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_812c0_row0_col8, #T_812c0_row2_col20, #T_812c0_row6_col27, #T_812c0_row15_col10, #T_812c0_row15_col28, #T_812c0_row17_col6, #T_812c0_row17_col22, #T_812c0_row19_col16, #T_812c0_row23_col24, #T_812c0_row24_col22, #T_812c0_row26_col10 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_812c0_row0_col9, #T_812c0_row2_col25, #T_812c0_row5_col8, #T_812c0_row16_col11, #T_812c0_row18_col11, #T_812c0_row18_col22, #T_812c0_row20_col0 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_812c0_row0_col10, #T_812c0_row23_col12, #T_812c0_row29_col17 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_812c0_row0_col12, #T_812c0_row2_col23, #T_812c0_row3_col11, #T_812c0_row4_col17, #T_812c0_row4_col21, #T_812c0_row6_col1, #T_812c0_row6_col5, #T_812c0_row6_col11, #T_812c0_row14_col3, #T_812c0_row16_col5, #T_812c0_row22_col5, #T_812c0_row24_col17, #T_812c0_row27_col25, #T_812c0_row30_col11 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_812c0_row0_col13, #T_812c0_row9_col28, #T_812c0_row14_col16, #T_812c0_row16_col4, #T_812c0_row16_col19, #T_812c0_row27_col24, #T_812c0_row27_col30, #T_812c0_row30_col14 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_812c0_row0_col14, #T_812c0_row2_col10, #T_812c0_row7_col27, #T_812c0_row13_col14, #T_812c0_row14_col27, #T_812c0_row22_col19, #T_812c0_row25_col27 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_812c0_row0_col16, #T_812c0_row5_col11, #T_812c0_row7_col14, #T_812c0_row8_col18, #T_812c0_row9_col22, #T_812c0_row10_col2, #T_812c0_row10_col8, #T_812c0_row11_col22, #T_812c0_row13_col16, #T_812c0_row15_col22, #T_812c0_row16_col7, #T_812c0_row17_col21, #T_812c0_row19_col11, #T_812c0_row25_col17, #T_812c0_row27_col12, #T_812c0_row27_col15, #T_812c0_row30_col22 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_812c0_row0_col17, #T_812c0_row2_col30, #T_812c0_row5_col10, #T_812c0_row7_col24, #T_812c0_row19_col4, #T_812c0_row21_col26, #T_812c0_row22_col26, #T_812c0_row24_col27, #T_812c0_row29_col16, #T_812c0_row29_col24, #T_812c0_row30_col18 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_812c0_row0_col18, #T_812c0_row2_col14, #T_812c0_row5_col1, #T_812c0_row6_col20, #T_812c0_row9_col4, #T_812c0_row25_col6, #T_812c0_row25_col22, #T_812c0_row27_col1, #T_812c0_row28_col5, #T_812c0_row30_col5 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_812c0_row0_col19, #T_812c0_row3_col18, #T_812c0_row7_col16, #T_812c0_row8_col24, #T_812c0_row11_col13, #T_812c0_row12_col14, #T_812c0_row12_col16, #T_812c0_row21_col30, #T_812c0_row24_col18, #T_812c0_row25_col26, #T_812c0_row27_col4 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_812c0_row0_col20, #T_812c0_row5_col17, #T_812c0_row7_col17, #T_812c0_row7_col19, #T_812c0_row10_col17, #T_812c0_row16_col12 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_812c0_row0_col21, #T_812c0_row9_col8, #T_812c0_row19_col7, #T_812c0_row30_col3 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_812c0_row0_col22, #T_812c0_row9_col3, #T_812c0_row13_col23, #T_812c0_row13_col25, #T_812c0_row17_col3, #T_812c0_row24_col25, #T_812c0_row26_col23, #T_812c0_row27_col0 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_812c0_row0_col23, #T_812c0_row1_col10 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_812c0_row0_col24, #T_812c0_row1_col19, #T_812c0_row4_col13, #T_812c0_row6_col19, #T_812c0_row13_col4, #T_812c0_row29_col4 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_812c0_row0_col25, #T_812c0_row1_col7, #T_812c0_row8_col4, #T_812c0_row9_col14, #T_812c0_row10_col26, #T_812c0_row11_col24, #T_812c0_row11_col30, #T_812c0_row12_col15, #T_812c0_row17_col19, #T_812c0_row18_col12, #T_812c0_row20_col4, #T_812c0_row21_col27, #T_812c0_row23_col28, #T_812c0_row24_col4, #T_812c0_row26_col18 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_812c0_row0_col27, #T_812c0_row1_col8, #T_812c0_row4_col24, #T_812c0_row4_col27, #T_812c0_row7_col13, #T_812c0_row10_col19, #T_812c0_row10_col24, #T_812c0_row11_col4, #T_812c0_row14_col18, #T_812c0_row15_col12, #T_812c0_row17_col10, #T_812c0_row17_col13, #T_812c0_row29_col15, #T_812c0_row30_col24 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_812c0_row0_col28, #T_812c0_row24_col30, #T_812c0_row29_col30 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_812c0_row0_col29, #T_812c0_row4_col9, #T_812c0_row4_col23, #T_812c0_row7_col20, #T_812c0_row11_col29, #T_812c0_row12_col9, #T_812c0_row12_col29, #T_812c0_row14_col11, #T_812c0_row15_col25 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_812c0_row0_col30, #T_812c0_row1_col27, #T_812c0_row20_col14 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_812c0_row1_col0 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_812c0_row1_col2, #T_812c0_row8_col30, #T_812c0_row11_col19, #T_812c0_row12_col18, #T_812c0_row19_col30, #T_812c0_row20_col30, #T_812c0_row28_col30 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_812c0_row1_col3, #T_812c0_row8_col19, #T_812c0_row23_col18 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_812c0_row1_col4, #T_812c0_row2_col12, #T_812c0_row3_col15, #T_812c0_row4_col15, #T_812c0_row10_col11, #T_812c0_row14_col4, #T_812c0_row18_col9, #T_812c0_row20_col9, #T_812c0_row20_col13, #T_812c0_row21_col14, #T_812c0_row25_col10, #T_812c0_row26_col20, #T_812c0_row27_col7 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_812c0_row1_col5, #T_812c0_row1_col6, #T_812c0_row4_col16, #T_812c0_row8_col15, #T_812c0_row9_col11, #T_812c0_row13_col11, #T_812c0_row14_col28, #T_812c0_row15_col14, #T_812c0_row16_col18, #T_812c0_row16_col22, #T_812c0_row17_col20, #T_812c0_row18_col27, #T_812c0_row20_col10, #T_812c0_row21_col4, #T_812c0_row21_col18, #T_812c0_row22_col12, #T_812c0_row23_col5

# %% [markdown]
# # Obtendo as features que podem ser incluídas no modelo

# %% [markdown]
# Optei por utilizar o feature selector Boruta

# %% [markdown]
# Devido a sintaxe do Boruta exigir array's do DataFrame, fazemos as modificações abaixo:

# %%
#x = base[['V1']].to_numpy()
#y = base[['Class']].to_numpy()

X_treino = base.drop(['Class'], axis = 1).to_numpy()
y_treino = base.Class.to_numpy()

X = base.drop(['Class'], axis =1)

# %% [markdown]
# # Algoritmo Boruta
#
# ## Porque utilizar o Boruta?
#
# Boruta é um selecionador de features para a criação dos modelos

# %%
###initialize Boruta
forest = RandomForestClassifier()
boruta = BorutaPy(
   estimator = forest,
    n_estimators = 10,
   max_iter = 20 # number of trials to perform
)

# %%
### fit Boruta (it accepts np.array, not pd.DataFrame)
boruta.fit(X_treino, y_treino)
# Out:
# BorutaPy(estimator=RandomForestClassifier(n_estimators=10,
#                                           random_state=RandomState(MT19937) at 0x225D0A87840),
#          max_iter=20, n_estimators=10,
#          random_state=RandomState(MT19937) at 0x225D0A87840)

# %%
### print results
green_area = X.columns[boruta.support_].to_list()
blue_area = X.columns[boruta.support_weak_].to_list()

# %%
print('features in the green area:', green_area)
print('features in the blue area:', blue_area)
# Out:
# features in the green area: ['Time', 'V3', 'V4', 'V5', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V14', 'V16', 'V17', 'V18', 'V20', 'V21', 'V26']
# features in the blue area: ['V1', 'V2', 'V6', 'V15', 'V19', 'V27', 'V28', 'Amount']

# %% [markdown]
# # Retirar dos dados as features que não foram apresentadas no Boruta

# %%
db = base.drop(['V13','V22','V23','V24','V25','Class'], axis =1)
y_db = base['Class']

# %% [markdown]
# Transformando as variáveis abaixo em Array's para entrar no Cross Validation

# %%
X_validacao = db.to_numpy()
y_validacao = y_db.to_numpy()

print(X_validacao)
print(y_validacao)
# Out:
# [[ 0.00000000e+00 -1.35980713e+00 -7.27811733e-02 ...  1.33558377e-01
#   -2.10530535e-02  1.49620000e+02]
#  [ 0.00000000e+00  1.19185711e+00  2.66150712e-01 ... -8.98309914e-03
#    1.47241692e-02  2.69000000e+00]
#  [ 1.00000000e+00 -1.35835406e+00 -1.34016307e+00 ... -5.53527940e-02
#   -5.97518406e-02  3.78660000e+02]
#  ...
#  [ 1.72788000e+05  1.91956501e+00 -3.01253846e-01 ...  4.45477214e-03
#   -2.65608286e-02  6.78800000e+01]
#  [ 1.72788000e+05 -2.40440050e-01  5.30482513e-01 ...  1.08820735e-01
#    1.04532821e-01  1.00000000e+01]
#  [ 1.72792000e+05 -5.33412522e-01 -1.89733337e-01 ... -2.41530880e-03
#    1.36489143e-02  2.17000000e+02]]
# [0 0 0 ... 0 0 0]

# %% [markdown]
# # Validação K-Fold
#
# ### Vamos utilizar o modelo de árvore de decisão inicialmente

# %%
clf = tree.DecisionTreeClassifier()

# %% [markdown]
# Vamos utilizar a função custo 'Recall' devido a necessidade de valorizar os casos Falsos Negativos.
#
# Abaixo, segue as modificações utilizadas para adaptar os códigos da função.
#
# Tais funções foram adaptadas Iniabasi Affiah, no site: https://www.section.io/engineering-education/how-to-implement-k-fold-cross-validation/

# %% [markdown]
# ### Através da modificação abaixo, é possível obter a expressão das funções custo, Acurácia, Precisão, F1_score e Recall.

# %%
def cross_validation(model, _X, _y, _cv=5):
      _scoring = ['accuracy','precision','recall','roc_auc', 'average_precision']
      results = cross_validate(estimator=model,
                               X=_X,
                               y=_y,
                               cv=_cv,
                               scoring=_scoring,
                               return_train_score=True)
      
      return {"Training Accuracy scores": results['train_accuracy'],
              "Mean Training Accuracy": results['train_accuracy'].mean()*100,
              "Training Precision scores": results['train_precision'],
              "Mean Training Precision": results['train_precision'].mean(),
              "Training Average precision scores": results['train_average_precision'],
              "Mean Training Average precision": results['train_average_precision'].mean(),
              "Training Roc_Auc": results['train_roc_auc'],
              "Mean Roc_Auc": results['train_roc_auc'].mean(),
              "Validation Accuracy scores": results['test_accuracy'],
              "Mean Validation Accuracy": results['test_accuracy'].mean()*100,
              "Validation Precision scores": results['test_precision'],
              "Mean Validation Precision": results['test_precision'].mean(),
              "Average Precision Score": results['test_average_precision'],
              "Mean Average Precision Score": results['test_average_precision'].mean(),
              "Roc Auc Score": results['test_roc_auc'],
              "Mean Roc Auc Score": results['test_roc_auc'].mean()
              }

# %%
def plot_result(x_label, y_label, plot_title, train_data, val_data):
        '''Function to plot a grouped bar chart showing the training and validation
          results of the ML model in each fold after applying K-fold cross-validation.
         Parameters
         ----------
         x_label: str, 
            Name of the algorithm used for training e.g 'Decision Tree'
          
         y_label: str, 
            Name of metric being visualized e.g 'Accuracy'
         plot_title: str, 
            This is the title of the plot e.g 'Accuracy Plot'
         
         train_result: list, array
            This is the list containing either training precision, accuracy, or f1 score.
        
         val_result: list, array
            This is the list containing either validation precision, accuracy, or f1 score.
         Returns
         -------
         The function returns a Grouped Barchart showing the training and validation result
         in each fold.
        '''
        
        # Set size of plot
        plt.figure(figsize=(12,6))
        labels = ["1st Fold", "2nd Fold", "3rd Fold", "4th Fold", "5th Fold"]
        X_axis = np.arange(len(labels))
        ax = plt.gca()
        plt.ylim(0.40000, 1)
        plt.bar(X_axis-0.2, train_data, 0.4, color='blue', label='Training')
        plt.bar(X_axis+0.2, val_data, 0.4, color='red', label='Validation')
        plt.title(plot_title, fontsize=30)
        plt.xticks(X_axis, labels)
        plt.xlabel(x_label, fontsize=14)
        plt.ylabel(y_label, fontsize=14)
        plt.legend()
        plt.grid(True)
        plt.show()

# %% [markdown]
# Plotando as métricas possíveis para incluir no DTC

# %%
sk.metrics.SCORERS.keys()
# Out:
# dict_keys(['explained_variance', 'r2', 'max_error', 'neg_median_absolute_error', 'neg_mean_absolute_error', 'neg_mean_absolute_percentage_error', 'neg_mean_squared_error', 'neg_mean_squared_log_error', 'neg_root_mean_squared_error', 'neg_mean_poisson_deviance', 'neg_mean_gamma_deviance', 'accuracy', 'top_k_accuracy', 'roc_auc', 'roc_auc_ovr', 'roc_auc_ovo', 'roc_auc_ovr_weighted', 'roc_auc_ovo_weighted', 'balanced_accuracy', 'average_precision', 'neg_log_loss', 'neg_brier_score', 'adjusted_rand_score', 'rand_score', 'homogeneity_score', 'completeness_score', 'v_measure_score', 'mutual_info_score', 'adjusted_mutual_info_score', 'normalized_mutual_info_score', 'fowlkes_mallows_score', 'precision', 'precision_macro', 'precision_micro', 'precision_samples', 'precision_weighted', 'recall', 'recall_macro', 'recall_micro', 'recall_samples', 'recall_weighted', 'f1', 'f1_macro', 'f1_micro', 'f1_samples', 'f1_weighted', 'jaccard', 'jaccard_macro', 'jaccard_micro', 'jaccard_samples', 'jaccard_weighted'])

# %% [markdown]
# # Rodando o K-Fold

# %% [markdown]
# Através das funções que foram modificadas acima, contextualizadas, vamos utilizar as modificações feitas anteriormente nas variáveis para desenvolver a validação cruzada e obter a função custo

# %%
Val = cross_validation(clf,X_validacao, y_validacao, _cv=5)
print(Val)

#Manaus isso aqui ta bom?

#Plotei os gráficos das normais pra ver como se distribuem
# Out:
# {'Training Accuracy scores': array([1., 1., 1., 1., 1.]), 'Mean Training Accuracy': 100.0, 'Training Precision scores': array([1., 1., 1., 1., 1.]), 'Mean Training Precision': 1.0, 'Training Average precision scores': array([1., 1., 1., 1., 1.]), 'Mean Training Average precision': 1.0, 'Training Roc_Auc': array([1., 1., 1., 1., 1.]), 'Mean Roc_Auc': 1.0, 'Validation Accuracy scores': array([0.00609178, 0.99910467, 0.9950668 , 0.99899932, 0.99892909]), 'Mean Validation Accuracy': 79.96383308002082, 'Validation Precision scores': array([0.00164015, 0.82432432, 0.2       , 0.68807339, 0.71264368]), 'Mean Validation Precision': 0.4853363101534239, 'Average Precision Score': array([0.00164608, 0.50858412, 0.12513936, 0.52699057, 0.45148822]), 'Mean Average Precision Score': 0.3227696697744124, 'Roc Auc Score': array([0.47193041, 0.8079665 , 0.80907898, 0.8823541 , 0.8161067 ]), 'Mean Roc Auc Score': 0.7574873378881006}

# %% [markdown]
# ### Plotando o Recall referente ao training e Validação do K-FOLD
#
# Podemos notar um grande indicativo de Overfit do Modelo

# %%
model_name = 'DecisionTree'
plot_result(model_name,
            "roc_auc",
            "Roc_Auc Score in 5 Folds",
            Val["Training Roc_Auc"],
            Val["Roc Auc Score"])
print(Val["Roc Auc Score"])
print(Val["Mean Roc Auc Score"])
# Out:
# [0.47193041 0.8079665  0.80907898 0.8823541  0.8161067 ]
# 0.7574873378881006

# %%
model_name = 'DecisionTree'
plot_result(model_name,
            "Average Precision",
            "Average Precision Score in 5 Folds",
            Val["Training Average precision scores"],
            Val["Average Precision Score"])
print(Val["Average Precision Score"])
# Out:
# [0.00164608 0.50858412 0.12513936 0.52699057 0.45148822]

# %% [markdown]
# # Alterando os valores de min_samples_split para 5

# %%
Decision2 = tree.DecisionTreeClassifier(criterion="entropy",
                                               min_samples_split=5,
                                               random_state=0)
Val2 = cross_validation(clf,X_validacao, y_validacao, _cv=5)
print(Val2)
# Out:
# {'Training Accuracy scores': array([1., 1., 1., 1., 1.]), 'Mean Training Accuracy': 100.0, 'Training Precision scores': array([1., 1., 1., 1., 1.]), 'Mean Training Precision': 1.0, 'Training Average precision scores': array([1., 1., 1., 1., 1.]), 'Mean Training Average precision': 1.0, 'Training Roc_Auc': array([1., 1., 1., 1., 1.]), 'Mean Roc_Auc': 1.0, 'Validation Accuracy scores': array([0.00610934, 0.999368  , 0.99513702, 0.99901687, 0.99899932]), 'Mean Validation Accuracy': 79.9726109171764, 'Validation Precision scores': array([0.00160502, 0.88888889, 0.21221865, 0.6875    , 0.74117647]), 'Mean Validation Precision': 0.5062778064376552, 'Average Precision Score': array([0.00161577, 0.64693865, 0.14348455, 0.54054724, 0.47708504]), 'Mean Average Precision Score': 0.3619342511707745, 'Roc Auc Score': array([0.46185578, 0.86355723, 0.83458039, 0.89254939, 0.82123512]), 'Mean Roc Auc Score': 0.7747555811875819}

# %%
model_name = 'DecisionTree'
plot_result(model_name,
            "Average Precision",
            "Average Precision Score in 5 Folds",
            Val2["Training Average precision scores"],
            Val2["Average Precision Score"])
print(Val2["Average Precision Score"])
# Out:
# [0.00161577 0.64693865 0.14348455 0.54054724 0.47708504]

# %%
model_name = 'DecisionTree'
plot_result(model_name,
            "roc_auc",
            "Roc_Auc Score in 5 Folds",
            Val2["Training Roc_Auc"],
            Val2["Roc Auc Score"])
print(Val2["Roc Auc Score"])
print(Val2["Mean Roc Auc Score"])
# Out:
# [0.46185578 0.86355723 0.83458039 0.89254939 0.82123512]
# 0.7747555811875819

# %% [markdown]
# # Resolvendo o problema de Overfit do Modelo de Arvore de decisão

# %% [markdown]
# Rodando o GridSearch para encontrar os melhores valores para os hyperparâmetros

# %%
param_grid = {
    "max_depth": [3,5,10],
    "min_samples_split": [2,5,7,10,20,30,40,50],
    "min_samples_leaf": [1,2,5,7,9,13,15,20,25]
}

clf = DecisionTreeClassifier()
grid_cv = GridSearchCV(clf, param_grid, scoring="roc_auc", n_jobs=-1, cv=5).fit(X_validacao, y_validacao)

# %%
print("Param for GS", grid_cv.best_params_)
print("CV score for GS", grid_cv.best_score_)
print(roc_auc_score(y_db, grid_cv.predict(X_validacao)))
# Out:
# Param for GS {'max_depth': 10, 'min_samples_leaf': 25, 'min_samples_split': 10}
# CV score for GS 0.9314837696841058
# 0.8759775706808649

# %%
Decision4 = tree.DecisionTreeClassifier(criterion="entropy",
                                               min_samples_split=10,
                                               random_state=0,
                                               max_depth = 5,
                                               min_samples_leaf = 25,)
Val4 = cross_validation(clf,X_validacao, y_validacao, _cv=5)
print(Val4)
# Out:
# {'Training Accuracy scores': array([1., 1., 1., 1., 1.]), 'Mean Training Accuracy': 100.0, 'Training Precision scores': array([1., 1., 1., 1., 1.]), 'Mean Training Precision': 1.0, 'Training Average precision scores': array([1., 1., 1., 1., 1.]), 'Mean Training Average precision': 1.0, 'Training Roc_Auc': array([1., 1., 1., 1., 1.]), 'Mean Roc_Auc': 1.0, 'Validation Accuracy scores': array([0.00610934, 0.99922756, 0.99813908, 0.99894665, 0.99889398]), 'Mean Validation Accuracy': 80.02633193346631, 'Validation Precision scores': array([0.00160502, 0.83950617, 0.46875   , 0.67272727, 0.69662921]), 'Mean Validation Precision': 0.5358435364486784, 'Average Precision Score': array([0.00161577, 0.57717473, 0.28765692, 0.50839908, 0.44135662]), 'Mean Average Precision Score': 0.3632406212411995, 'Roc Auc Score': array([0.46185578, 0.84332003, 0.80552452, 0.87723447, 0.81608912]), 'Mean Roc Auc Score': 0.7608047838531633}

# %%
model_name = 'DecisionTree'
plot_result(model_name,
            "roc_auc",
            "Roc_Auc Score in 5 Folds",
            Val4["Training Roc_Auc"],
            Val4["Roc Auc Score"])
print(Val4["Roc Auc Score"])
print(Val4["Mean Roc Auc Score"])
# Out:
# [0.46185578 0.84332003 0.80552452 0.87723447 0.81608912]
# 0.7608047838531633

# %%
# Rodar a DTC forçando os dados 

X_train, X_test, y_train, y_test = train_test_split(X_validacao, y_validacao, test_size=0.3, random_state=0)
clf_2 = tree.DecisionTreeClassifier(criterion="entropy",
                                               min_samples_split=10,
                                               random_state=0,
                                               max_depth = 5,
                                               min_samples_leaf = 25,)
clf_2.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=25,
#                        min_samples_split=10, random_state=0)

# %%
probs1 = clf_2.predict_proba(X_test)[:,1] # Probabilidades de SER FRAUDE (Ser BOM)


# Cálculo da área sobre a curva
auc_model1 = roc_auc_score(y_test, probs1)

# Cálculo dos rates para plot da Curva ROC
fpr_model1, tpr_model1, _ = roc_curve(y_test, probs1)

#Plotagem
plt.figure(figsize=(6,6))
plt.plot([0, 1], [0, 1], '--', color='orange', lw=2)
plt.plot(fpr_model1, tpr_model1, marker='.', label='DTC (AUC = %0.3f)' % auc_model1)
plt.title('Curva ROC')
plt.xlabel('% Falso Positivo')
plt.ylabel('% Verdadeiro Positivo')
plt.legend()
plt.show()

# %%
test_predictions = clf_2.predict(X_test)

# %% [markdown]
# # Função custo - Plotagem

# %% [markdown]
# Não podemos tirar interpretação abaixo, por se tratar de dados desbalanceados

# %%
print(classification_report(y_test, test_predictions, target_names=['NÃO FRAUDE','FRAUDE']))
# Out:
#               precision    recall  f1-score   support
#
#   NÃO FRAUDE       1.00      1.00      1.00     85296
#       FRAUDE       0.93      0.69      0.79       147
#
#     accuracy                           1.00     85443
#    macro avg       0.96      0.84      0.89     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# # Modelo de Regressão Logística

# %% [markdown]
# ### Aplicar SMOTE.
